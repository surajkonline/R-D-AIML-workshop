# %%
#@title
import numpy as np
import pandas as pd

# %%
# For unzipping 
from zipfile import ZipFile
file_name = '/content/12. December 2021.zip'#Check the zipped file path from "Copy path"
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
df10= pd.read_excel("/content/df11.xlsx", index_col=0) # Load the old excel file , df10 in this case
print('Done')
# Out:
# Done

# %%
# Upload three fies CMT, IPI, WD for the date which you want to add
df1= pd.read_csv("/content/12. December 2021/12122021/CMT.csv")
df2= pd.read_csv("/content/12. December 2021/12122021/IPI.csv")
df3= pd.read_csv("/content/12. December 2021/12122021/WD CUT.csv")
print('Done')
# Out:
# Done

# %%
#@title
df2.drop(df2.iloc[:, 0:11], inplace = True, axis = 1)
df2.drop(df2.columns[[1,2,3,6,7,10,11,13,15]], axis = 1, inplace = True)
df3.drop(df3.iloc[:, 0:9], inplace = True, axis = 1)
df3.drop(df3.iloc[:, 1:6], inplace = True, axis = 1)
df3.drop(df3.iloc[:, 14:22], inplace = True, axis = 1)
df = pd.concat([df1, df2,df3], axis=1)
first_column = df.pop('Clearer Type')
df.insert(9,'Clearer Type', first_column)
print('Done')

# %%
df12 = pd.concat([df11, df])# If you are adding 11th day name it df11
# Add all days one by one

# %%
#@title
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (2.5.9)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.1.0)

# %%
# To print new excel file 
writer = pd.ExcelWriter('df12.xlsx') # Name the file you want
df12.to_excel(writer, sheet_name= "Sheet1") # Use the same name as above 
writer.save()
print('DataFrame is written successfully to Excel File.')
# Out:
# DataFrame is written successfully to Excel File.
